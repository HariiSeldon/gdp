# %%
import pandas as pd

# %%
life_gpd = pd.read_excel('C:\\Users\\55169\\Desktop\\Life-Expectancy-and-GDP-Starter\\Life-Expectancy-and-GDP-Starter\\advanced.xlsx')

# %%
life_gpd.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.129152e+14  2.180944e+14  2.370806e+13  2.821128e+14
# 2  NY.GDP.MKTP.CD  5.377778e+14  5.488889e+14  5.466667e+14  7.511112e+14
# 3  NY.GDP.MKTP.CD  1.040414e+12  1.112789e+14  1.194319e+14  1.267633e+14
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2014          2015          2016  \
# ...
